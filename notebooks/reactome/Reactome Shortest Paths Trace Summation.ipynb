# %% [markdown]
# # Create all shortest path traces with reactome db

# %% [markdown]
# The biggest difference from biocyc is entity mapping.  It is a lot more complicated since Reactome does not have a consistent ID.

# %%
# install lifelike_gds package if not already installed (e.g. running in Google Colab)
import importlib

if importlib.util.find_spec('lifelike_gds') is None:
  # !pip install git+https://github.com/SBRG/GDS-Public

# provide the path to the notebook folder in the github repository in case the notebook is run in Google Colab
github_path = 'SBRG/GDS-Public/main/notebooks/reactome'

# %%
import os
import warnings
from pathlib import PurePosixPath

# %%
# Import GDS modules
from lifelike_gds.network.shortest_paths_trace import ShortestPathTrace
from lifelike_gds.arango_network.reactome import *
from lifelike_gds.network.trace_graph_utils import *
from lifelike_gds.arango_network.reactome_notebook_functions import *
# Out:
# /Users/dommas/.local/share/virtualenvs/GDS-Public-uKBS7cUg/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Settings
# Make sure to change to the correct one based on your local settings

# %%
# Directory where to look for input data
input_dir = PurePosixPath('input')

# Directory where to output results
output_dir = PurePosixPath('output')
os.makedirs(output_dir, exist_ok=True)

# Reactome arango database connection parameters
# If you are running this notebook from Lifelike's online training BinderHub website,
# then these paremeters are already set for you in the environment.
arango_dbname = os.getenv('REACTOME_ARANGO_DATABASE', 'ecocyc-25')

# %% [markdown]
# ## Parameters
# Set parameters
# - source_name: name for the source entities.
# - target_name: name for the target entities.
# - source_file: source file name in input dir
# - target_file: target file name in input dir

# %%
source_name = 'il6'
target_name = 'vegfa'

# %% [markdown]
# ## Define functions to get source/target nodes
# - read input file with ids (stId or dbId)
# - read input file with reference ids (gene_id or chebi_id)

# %% [markdown]
# ## Define functions to export shortest paths traces to graph file

# %% [markdown]
# ## Connect to arango database

# %%
database = ReactomeDB(arango_dbname)

# %% [markdown]
# ## Load graph from arango graph database to memery

# %%
tracegraph = ShortestPathTrace(Reactome(database))

# set up output directory where the excel and graph files will write to
tracegraph.datadir = output_dir

# initiate tracegraph by loading graph data from arango
# a networkx graph is created here.
tracegraph.init_default_graph()
# Out:
# INFO: load reactome graph
# ---------------------------------------------------------------------------
# AQLQueryExecuteError                      Traceback (most recent call last)
# Cell In[8], line 8
#       4 tracegraph.datadir = output_dir
#       6 # initiate tracegraph by loading graph data from arango
#       7 # a networkx graph is created here.
# ----> 8 tracegraph.init_default_graph()
#
# File ~/Projects/GDS-Public/src/lifelike_gds/arango_network/trace_graph_nx.py:40, in TraceGraphNx.init_default_graph(self, exclude_currency, exclude_secondary)
#      39 def init_default_graph(self, exclude_currency=True, exclude_secondary=True):
# ---> 40     self.graphsource.initiate_trace_graph(self, exclude_currency, exclude_secondary)
#
# File ~/Projects/GDS-Public/src/lifelike_gds/arango_network/reactome.py:283, in Reactome.initiate_trace_graph(self, tracegraph, exclude_secondary_metabolites, exclude_secondary)
#     263     rel_lists_query = ','.join(
#     264         f"""
#     265             (
#    (...)
#     270         """ for rel in REACTOME_TRACE_RELS
#     271     )
#     272     rel_query = f"""
#     273         FOR n IN UNION_DISTINCT(
#     274             {rel_lists_query}
#    (...)
#     281             }
#     282     """
# --> 283 tracegraph.add_nodes(node_query)
#     284 tracegraph.add_rels(rel_query)
#     285 logging.info(nx.info(tracegraph.graph))
#
# File ~/Projects/GDS-Public/src/lifelike_gds/arango_network/trace_graph_nx.py:49, in TraceGraphNx.add_nodes(self, node_query, **parameters)
#      45 def add_nodes(self, node_query, **parameters):
#      46     """
#      47     @param node_query a query that return node id (arango-id), e.g match(n) return id(n) as node_id;
#      48     """
# ---> 49     node_data = self.graphsource.database.get_dataframe(node_query, **parameters)
#      50     nodes = [n for n in node_data['node_id']]
#      51     self.graph.add_nodes_from(nodes)
#
# File ~/Projects/GDS-Public/src/lifelike_gds/arango_network/database.py:43, in Database.get_dataframe(self, query, **kwparameters)
#      42 def get_dataframe(self, query: str, **kwparameters) -> pd.DataFrame:
# ---> 43     results = self.run_query(query, **kwparameters)
#      44     df = pd.DataFrame(results)
#      45     return df
#
# File ~/Projects/GDS-Public/src/lifelike_gds/arango_network/database.py:33, in Database.run_query(self, query, **kwparameters)
#      32 def run_query(self, query, **kwparameters):
# ---> 33     cursor = self.db.aql.execute(query, bind_vars=kwparameters)
#      34     result = [r for r in cursor]
#      35     return result
#
# File ~/.local/share/virtualenvs/GDS-Public-uKBS7cUg/lib/python3.9/site-packages/arango/aql.py:442, in AQL.execute(self, query, count, batch_size, ttl, bind_vars, full_count, max_plans, optimizer_rules, cache, memory_limit, fail_on_warning, profile, max_transaction_size, max_warning_count, intermediate_commit_count, intermediate_commit_size, satellite_sync_wait, stream, skip_inaccessible_cols, max_runtime, fill_block_cache, allow_dirty_read, allow_retry)
#     439         raise AQLQueryExecuteError(resp, request)
#     440     return Cursor(self._conn, resp.body, allow_retry=allow_retry)
# --> 442 return self._execute(request, response_handler)
#
# File ~/.local/share/virtualenvs/GDS-Public-uKBS7cUg/lib/python3.9/site-packages/arango/api.py:74, in ApiGroup._execute(self, request, response_handler)
#      63 def _execute(
#      64     self, request: Request, response_handler: Callable[[Response], T]
#      65 ) -> Result[T]:
#      66     """Execute an API.
#      67
#      68     :param request: HTTP request.
#    (...)
#      72     :return: API execution result.
#      73     """
# ---> 74     return self._executor.execute(request, response_handler)
#
# File ~/.local/share/virtualenvs/GDS-Public-uKBS7cUg/lib/python3.9/site-packages/arango/executor.py:68, in DefaultApiExecutor.execute(self, request, response_handler)
#      59 """Execute an API request and return the result.
#      60
#      61 :param request: HTTP request.
#    (...)
#      65 :return: API execution result.
#      66 """
#      67 resp = self._conn.send_request(request)
# ---> 68 return response_handler(resp)
#
# File ~/.local/share/virtualenvs/GDS-Public-uKBS7cUg/lib/python3.9/site-packages/arango/aql.py:439, in AQL.execute.<locals>.response_handler(resp)
#     437 def response_handler(resp: Response) -> Cursor:
#     438     if not resp.is_success:
# --> 439         raise AQLQueryExecuteError(resp, request)
#     440     return Cursor(self._conn, resp.body, allow_retry=allow_retry)
#
# AQLQueryExecuteError: [HTTP 404][ERR 1203] AQL: collection or view not found: activeUnitOf (while parsing)

# %% [markdown]
# ## Get source and target nodes
# Make sure to choose the right method to get the nodes

# %%
source_ids = ['R-HSA-447100']
source_nodes = database.get_nodes_by_attr(source_ids, 'stId')
print('stIds:', len(source_ids), ', nodes matched:', len(source_nodes))

# %%
target_ids = ['R-HSA-2975974']
target_nodes = database.get_nodes_by_attr(target_ids, 'stId')
print('stIds:', len(target_ids), ', nodes matched:', len(target_nodes))

# %% [markdown]
# ## Create (sankey) graph file for shortest paths

# %%
write_shortest_paths(
    tracegraph, source_name, source_nodes, target_name, target_nodes
)
